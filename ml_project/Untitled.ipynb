# %%
import pandas as pd
import os
from typing import List, Tuple
import numpy as np

## LOad raw Data 
def load_articles(data_folder: str) -> pd.DataFrame:
    """
    Load the articles as pandas dataframe

    Keyword arguments:
        data_folder -- the path to the folder that contains the data

    Returns:
        pandas dataframe containing the article data
    """
    return pd.read_csv(
        open(os.path.join(data_folder, "raw-data.csv"), encoding="latin_1")
    )


# Load the tags (Useless)
def load_tags(data_folder: str) -> List[str]:
    """
    Load the tag names as list

    Keyword arguments:
        data_folder -- the path to the folder that contains the data

    Returns:
        list of tag names. The index of the tags in the list are the ids of the tags
    """
    tags = []
    with open(os.path.join(data_folder, "tags.dat")) as tag_file:
        for tag in tag_file.readlines():
            tags.append(tag.strip())
    return tags

## Article id -> tag matching
def load_article_tags(data_folder: str) -> List[List[str]]:
    """
    Load the tags for each article

    Keyword arguments:
        data_folder -- the path to the folder that contains the data

    Returns:
        list of tags per article. This is represented as a 2d list. Each element of the outer list
        represents the article at that index in the pandas Dataframe. The inner lists contain the
        tag ids for each article. So to get the first tag name for the first article you would call:
        tags[article_tags[0][0]]
    """
    item_tag = []
    with open(os.path.join(data_folder, "item-tag.dat")) as item_tag_file:
        for i, line in enumerate(item_tag_file.readlines()):
            item_tag.append([int(tag) for tag in line.strip().split()[1:]])
    return item_tag


def load_citations(data_folder: str, num_articles: int = 16980) -> np.ndarray:
    """
    Load the citation network

    Keyword arguments:
        data_folder -- the path to the folder that contains the data
        num_articles -- the number of articles in the dataset

    Returns:
        square 2d numpy matrix with citation information about articles.
        The citation matrix is num_articles X num_articles.
        There is a 1 in locations in which there is a citation between articles a -> b
        citations[a][b] and 0 otherwise.
    """
    citations = np.zeros([num_articles, num_articles])
    with open(os.path.join(data_folder, "citations.dat")) as citations_file:
        for i, line in enumerate(citations_file.readlines()):
            for citation in line.strip().split()[1:]:
                citations[i][int(citation)] = 1
    return citations

## train data user->article matching
def load_user_article_likes(
    data_folder: str, num_users: int = 5551, num_articles: int = 13584
) -> np.ndarray:
    """
    Load the article likes for each user

    Keyword arguments:
        data_folder -- the path to the folder that contains the data
        num_users -- the number of users in the dataset - default is 5551
        num_articles -- the number of articles in the dataset - default is 13584

    Returns:
        2d numpy matrix with describing user like information.
        This matrix is num_users X num_articles.
        There is a 1 in locations in which a user likes an article u -> a
        citations[u][a] and 0 otherwise.
    """
    user_items = np.zeros([num_users, num_articles])
    with open(os.path.join(data_folder, "train_data.dat")) as users_file:
        for i, line in enumerate(users_file.readlines()):
            for article in line.strip().split()[1:]:
                user_items[i][int(article)] = 1
    return user_items


def load_articles_and_user_article_likes(
    data_folder: str,
) -> Tuple[pd.DataFrame, np.ndarray]:
    """
    Load both the article dataframe and the user article likes numpy array.

    Keyword arguments:
        data_folder -- the path to the folder that contains the data

    Returns:
        Tuple
        First element is a dataframe containing article info
        Second is 2d numpy matrix with describing user like information.
    """
    articles_df = load_articles(data_folder)
    user_article_likes = load_user_article_likes(data_folder)
    return (articles_df, user_article_likes)

# %%
raw_data = load_articles('data')

# %%
raw_data.head(10)
# Out:
#    doc.id                                              title  citeulike.id  \
# 0       1  the metabolic world of escherichia coli is not...          42.0
# 1       2       reverse engineering of biological complexity          43.0
# 2       3                         exploring complex networks          44.0
# 3       4  comparative assessment of largescale data sets...          46.0
# 4       5                        navigation in a small world          47.0
# 5       6  random graphs with arbitrary degree distributi...          48.0
# 6       7  artificial gene networks for objective compari...          49.0
# 7       8  the segment polarity network is a robust devel...          50.0
# 8       9        the evolutionary origin of complex features          52.0
# 9      10  early language acquisition cracking the speech...          60.0
#
#                                            raw.title  \
# 0  The metabolic world of Escherichia coli is not...
# 1       Reverse Engineering of Biological Complexity
# 2                         Exploring complex networks
# 3  Comparative assessment of large-scale data set...
# 4                        Navigation in a small world
# 5  Random graphs with arbitrary degree distributi...
# 6  Artificial gene networks for objective compari...
# 7  The segment polarity network is a robust devel...
# 8       The evolutionary origin of complex features.
# 9  Early language acquisition: cracking the speec...
#
#                                         raw.abstract
# 0  To elucidate the organizational and evolutiona...
# 1  Advanced technologies and biology have extreme...
# 2  The study of networks pervades all of science,...
# 3  Comprehensive protein protein interaction maps...
# 4  The small-world phenomenon â the principle t...
# 5  Recent work on the structure of social network...
# 6  Motivation: Large-scale gene expression profil...
# 7  All insects possess homologous segments, but s...
# 8  A long-standing challenge to evolutionary theo...
# 9  Infants learn language with remarkable speed, ...

# %%
tags = load_tags('data')
tags
# Out:
# ['ucsc-browser',
#  'rr_interval',
#  'userscripts',
#  'newsciencenetwork',
#  'sequence_similarity_search',
#  'naturalcapital',
#  'spiders',
#  'localized',
#  'segmentation_algorithm',
#  'polymer_physics',
#  'tandem-repeats',
#  'gene_orthology',
#  'ontologylearning',
#  'environmental_effects',
#  'originality',
#  'trial_and_error',
#  'fundation',
#  '12_mar_10',
#  'ioannidis',
#  'canem',
#  'mahalanobis_distance',
#  'climate_variability',
#  'eugenics',
#  'appropriation',
#  'communicating-uncertainty',
#  'chemical_reaction_network_theory',
#  'bringing',
#  'advices',
#  'berryphase',
#  'noncoding_rna',
#  'tcbr',
#  'disease-network',
#  'circuitry',
#  'digital_researcher',
#  'elgar',
#  'projeto_tese',
#  'geraint-rees',
#  'ligation_independent_cloning',
#  'fisherinformation',
#  'oscilaltions',
#  'regulatory_nw_inference',
#  'cybermetrics',
#  'preface',
#  'feasibility',
#  'open_innovation',
#  'network_graphs',
#  'dft_general',
#  'reengineering',
#  'scraped',
#  'molecule_detection',
#  'errors',
#  'paired-end',
#  'neuroprosthesis',
#  'graphssocial-networks',
#  'interval_mapping',
#  '0_wikis',
#  'video_retrieval',
#  'de-contextualise',
#  '0_formalization',
#  'usenet',
#  'probabalistic_models',
#  'designing',
#  'databank',
#  'acertainment',
#  'evolutionism',
#  'widget',
#  'sequence-alignment',
#  'litreview2008',
#  'litreview2009',
#  'hardware_infrastructure',
#  'webgraph',
#  'legge-elena',
#  'china',
#  'internet_routing',
#  'james-taylor',
#  'metaphor_concept',
#  'epigenome',
#  'ciberliteratura_unam',
#  'kids',
#  'a_rna_structure_prediction_check',
#  'dendritic_rna',
#  'scaling-law',
#  'watts-strogatz-model',
#  'controversy',
#  'collegestudents',
#  'generic_method',
#  'sidechains',
#  'e8',
#  'golden',
#  'topography',
#  'projection',
#  'coricelli',
#  'refractoryperiod',
#  'edge-exchange',
#  'classification_of_sentences',
#  'ssaha2',
#  'multigene_families',
#  'repurpose',
#  'crawlers_general',
#  'p47',
#  'user-interest-modeling',
#  '20101116000062',
#  'mg1655',
#  'dnf',
#  'dna',
#  'portugal',
#  'kernel-pca',
#  'nmrorderparameters',
#  'dnh',
#  'lme',
#  'data-warehouse',
#  't-cell',
#  'music',
#  'musil',
#  'skewness',
#  'populations',
#  'nima-mosammaparast',
#  'generating_processes',
#  'multi-channel',
#  'yahoo',
#  'ta-algorithm',
#  'sensory-learning',
#  'class-s09',
#  'p4p',
#  'a_software',
#  'karen-eilbeck',
#  'locked',
#  '081220',
#  'behavioural-genetics',
#  'post_modernism',
#  'imagingvis',
#  'pdyn',
#  'ligand_optimization',
#  'classification_features',
#  'pseudo-euclidean-space',
#  'dalila-pinto',
#  'density-functional-theory',
#  'evo_psy',
#  'information-seeking_behavior',
#  'mod-grav',
#  'absolute',
#  'u24',
#  'binding_domains',
#  'electrical-engineering',
#  'lipid-bilayer',
#  'travel',
#  'sanatoriums',
#  'homo-sapiens',
#  'microrna-networks',
#  'gnosisphere',
#  'networks_dynamic',
#  'micropillars',
#  'oceans',
#  'causal_modelling',
#  'sigsna',
#  'method_terminology',
#  'webcrawler',
#  'query_substitution',
#  'sasha-tkachev',
#  'seda',
#  'joseph-dada',
#  'lc_ms',
#  'pastoral_societies',
#  'signed-network',
#  't2dm',
#  'cameraphone',
#  'recombination',
#  'rapid-prototyping',
#  'comparative_metabolomics',
#  'roundtripping',
#  'material_artefacts',
#  'eigenfaces',
#  'learning_based_vision',
#  'mathematical_modeling',
#  'motifpaper',
#  'mcherry',
#  'staghunt',
#  'word-similarity',
#  'science_and_culture',
#  'antihypertenseurs',
#  'sidekicks',
#  'optical-tweezers',
#  'concurrency',
#  'lp_norms',
#  'fip',
#  'ligand',
#  'fit',
#  'fractal',
#  'pyosequencing',
#  'arts_12_nov',
#  'legislative-bargaining',
#  'project-proposal',
#  'fin',
#  'non-random',
#  'fil',
#  'cir_2009',
#  'ubiqitous',
#  'quantumstatetomography',
#  'small-molecule-docking',
#  'proj_assembly',
#  'yeast-two-hybrid',
#  'basics',
#  'effects',
#  'working-memory',
#  'multidimensional',
#  'webreports',
#  'is200',
#  'short-read-alignment',
#  'mean_shift',
#  'gamma-waves',
#  'arrow',
#  'autonomia',
#  'featural_processing',
#  'coloured_petri_nets',
#  'teaching-ir',
#  'burial',
#  'log-normal',
#  'c-survey',
#  'marrink04pdf',
#  'hippocampe',
#  'design_principles',
#  'world-of-warcraft',
#  'web_usage',
#  'adaptivity',
#  'protein-protein_interface_conservation',
#  'mir_regulators',
#  'self-',
#  'shift-reduce',
#  'translational-research',
#  'enviroment',
#  'mason',
#  'combinatorial',
#  'biodiversiy',
#  'adapt',
#  'integrity_of_research',
#  'neutralinos',
#  'ines-barroso',
#  'educational_hypermedia',
#  'ant_colony',
#  'rank-n-polymorphism',
#  'joint_attention',
#  'avexis',
#  'estimate',
#  'chromatin-ip',
#  'laura_psicko_kilarski',
#  'mvvk06a',
#  'reiser',
#  'flairs-09',
#  'yeaast',
#  'cancer_therapy',
#  'bookmark',
#  'graphene-substrate',
#  'selfx',
#  'marino-zerial',
#  'lie_algebra',
#  'anonymisation',
#  'hetero_plasticity',
#  'mirna-target-database',
#  'verkehrsdatenanalyse',
#  'foundations-of-human-sociality',
#  'research_strategy',
#  'constraint_analysis',
#  'nisze_ekologiczne',
#  'laser_particle_acceleration',
#  'rjmcmc',
#  'behaviourism',
#  'igarashi',
#  'ant-colony-optimization',
#  'service',
#  'cognitive_capacity',
#  'temporal-evolutionweb-evolutionweb-dynamics',
#  'modular_response_analysis',
#  'berrys_phase',
#  'manifold-lle',
#  'master',
#  'capsas',
#  'lifesciences',
#  'genesis',
#  'molecular-structures',
#  'rewards',
#  'tasi',
#  'geodesic-active-contours',
#  'enterprise_engineering',
#  'biomodels',
#  'nanotec',
#  'automatic_process',
#  'bt2012',
#  'drosophila_melanogaster',
#  'designability',
#  'yeast_genome_ptn_no',
#  'pssm',
#  'regulator',
#  'science_magazine',
#  'beliefpropagation',
#  'statisticalinference',
#  'feeling',
#  'atp9pub',
#  'lisplang',
#  'distribuciones',
#  'imt595',
#  'miscellanea',
#  'myositis',
#  'spectrum',
#  'regulation_evolution',
#  'cse181',
#  'stimulusresponseassociation',
#  'royal_jelly',
#  'arousal',
#  'capacity_limitations',
#  'social-archives',
#  'foundational',
#  'register-machines',
#  'vgi',
#  'dihedral_angle',
#  'ant_colony_optimization',
#  'n_back',
#  'bayesian-network-extension',
#  'phase-reset',
#  'model_parameters',
#  'modular_programming',
#  'rank_fusion',
#  'alexander-pearlman',
#  'object_constancy',
#  'simulated-annealing',
#  'resource-discovery',
#  'harmonic_oscillator',
#  'curiosity_driven_read',
#  'activitydetection',
#  'binding_motif',
#  'metrics',
#  'mouth',
#  'minimalgenome',
#  'defense_review',
#  'eleven-simple-rules',
#  'singer',
#  'shrinkage_covariance',
#  'bioinformatics_career',
#  'evidence_based',
#  'information_transfer',
#  'scott-gordon',
#  'tech',
#  'dna_protein_interactions',
#  'hastings',
#  'nominalization',
#  'recommender-systems',
#  'terese',
#  'anti-aging-cmpds',
#  'cited_by_persaud',
#  'evolutionary-games',
#  'inpainting',
#  'kinase',
#  'fieldmap',
#  'energy_usage',
#  'clicker',
#  'early-warning',
#  'por-conseguir',
#  'future_studies',
#  'rich',
#  'rice',
#  'weimann',
#  'rarevariants',
#  'f1atpase',
#  'disequlibrium',
#  'new-kind-of-arrogance',
#  'expression_systems',
#  'non-essentialism',
#  'candiate-gene',
#  'alliance_theory',
#  'information-access',
#  'network_propagation',
#  'organization_theory',
#  'superfamily',
#  'modele_de_langue',
#  'aamc',
#  'functional_divergence',
#  'molecular_dynamics_simulation',
#  'digital_gene_expression',
#  'patch',
#  'crticism',
#  'molpunceqm',
#  'random_edge_exchange',
#  'sensitivity',
#  'foundations-of-quantum-theory',
#  'irena-spasic',
#  'photo2search',
#  'community_health',
#  'multislice-networks',
#  'xy_model',
#  'playfulness',
#  'irp',
#  'irr',
#  'suboptimal-solution',
#  'irt',
#  'incremental_learning',
#  'navigation-support',
#  'irk',
#  'evolution-organelle',
#  'extremal-science',
#  'irc',
#  'ird',
#  'ire',
#  'irg',
#  'cnvseq',
#  'extend',
#  'nature',
#  'wobbly-types',
#  'search-benchmark',
#  'boundary-domains',
#  'latitudinal_gradient',
#  'tag-semantic',
#  'percentage_identity',
#  'operational_semantics',
#  'risc-ip',
#  'institute_of_scientific_information',
#  'p-darkness',
#  'selection_purifying',
#  'gene_names',
#  'madeleine_peyroux',
#  'landscape_preference',
#  'himalayas',
#  'exon_and_domain_shuffling',
#  '0_software_quality',
#  'formalismus',
#  'mutation_as_noise_in_evolutionary_dynamics',
#  'global-variables',
#  '18srrna',
#  'protein_pathways',
#  'designing_participation',
#  'ant-based',
#  'technoethics',
#  'novel_gene',
#  'review-entanglement',
#  'local-feature',
#  'process_mining',
#  'transcription-factors',
#  'estrategia',
#  'kinect',
#  'fre',
#  'learning-motor',
#  'modal-logic',
#  'edit-distance',
#  'frp',
#  'data-dredging',
#  'pi_calculus',
#  'allelic',
#  'query_sessions',
#  'regua',
#  'benjamin-yukich',
#  'automative',
#  'fibroblast',
#  'semeval',
#  'mrlqsr',
#  'spie',
#  'echo-state-network',
#  'spin',
#  'malondialdehyde',
#  'spim',
#  'cul',
#  'participatory',
#  'intac',
#  'stemcell',
#  'sketch_interface',
#  'consensus_approach',
#  'strong-normalization',
#  'f-divergence',
#  'web_20',
#  'md_fox',
#  'unstructured_text',
#  'data-structures',
#  'wisdom-of-crowds',
#  'genetics-and-popular-culture',
#  'relationalmodel',
#  'politicalscience',
#  'semantic-technologies',
#  'modern_approach',
#  'blandaltman',
#  'statemate',
#  'parietal_cortex',
#  'arrival_dates',
#  'colorectal-cancer',
#  'socio-economic-systems',
#  'collective_knowledge',
#  'kay-nieselt',
#  'sapir-whorf',
#  'buried-surface',
#  'fast_approach',
#  'biomodelsdb',
#  'horizontal-transfer',
#  'judgement',
#  'structuration_theory',
#  'weiguo-feng',
#  'computer-modelling',
#  'tomkins',
#  'prefrontal-columns',
#  'academic',
#  'academia',
#  'geometric_features',
#  'corporate',
#  'multimedieprodktion',
#  'etica',
#  'antagonists',
#  'psychometrics',
#  'homogeneity',
#  'tree_comparison',
#  'lasso',
#  'bioremediation',
#  'sentisitve',
#  'han',
#  'annovar',
#  'hac',
#  'genome-splicings',
#  '30-oct-09',
#  'karin-radrich',
#  'fortran',
#  'target_mrna',
#  'dynamic_web_pages',
#  'har',
#  'has',
#  'hat',
#  'vant_veer',
#  'structure_identification_from_data',
#  'spectral-clusetring',
#  'metrics-diversity',
#  'denier',
#  'elders',
#  'survival',
#  'orbitofrontal_complex',
#  'quakeatl',
#  'pbmc',
#  'plos_education',
#  'global_cities',
#  'rev_ref',
#  'cross-correlations',
#  'raoul-frijters',
#  'critical-phenomenon',
#  'specific_gene_expression',
#  'fuckinieee',
#  'alice',
#  'litpres',
#  'missing_data',
#  'segment_polarity_genes',
#  'time-series',
#  'social_scholarship',
#  'warping',
#  'multi-sensory',
#  'crowd',
#  'set_usuarios',
#  'relaxation_response',
#  'whyline',
#  'crows',
#  'jonas-almeida',
#  'learning-algorithm',
#  'commercial_establishment',
#  'spontaneous-activity',
#  'online-community',
#  'genetic_markers',
#  'microeconomic_theory',
#  'golder',
#  'movement-science',
#  'treadmill',
#  'similarity_measures',
#  'microbial_communities',
#  'sociotechnical',
#  'matrix_factorization',
#  'aa-residue-coupling',
#  'pj-unfolded',
#  'barcode',
#  'phenonmen_analysis',
#  'quantitative-pcr',
#  'epigen',
#  'text_categorization',
#  'automatie-experiment',
#  'experimental_method',
#  'natural_divisions',
#  'structured-illumination',
#  'signed-networks',
#  'protein_dna',
#  'protein-translation',
#  'anomalous',
#  'systems_biology_results_markup_language',
#  'cis_regulation',
#  'prosem-paper',
#  'in_silico_evolution',
#  'ribozymes',
#  'acot',
#  'strengths_and_weaknesses',
#  'data_base',
#  'groupwork',
#  'mbd',
#  'maxwell',
#  'mba',
#  'mbb',
#  'cell_biomechanics',
#  'system-biology',
#  'mbt',
#  'boundaryobjects',
#  'in_silico',
#  'mbw',
#  'markov_chain_monte_carlo',
#  'nash-equilibrium',
#  'cognitive_functions',
#  'mol_mot_essay',
#  'aso',
#  'coevoluion_interface',
#  'sense_disambiguation',
#  'ontology_tool',
#  'altitude',
#  'academic_article',
#  'tamd',
#  'sheaf-theory',
#  'grasping',
#  'wordpress',
#  'predicate_logic',
#  'tams',
#  'multitest',
#  'e_coli',
#  'virtual-community',
#  'thesaurus',
#  'algae-classification',
#  'power_conservation',
#  'social-study-science',
#  'mglur5_paper',
#  'algorith',
#  'daniel-zerbino',
#  'feral-hypertext',
#  'toolkits',
#  'arrays',
#  'adicition',
#  'designed_mutations',
#  'global_scale',
#  'finite-automaton',
#  'disease_propagation',
#  'tam2',
#  'publish-or-perish',
#  'ngs_crops',
#  'dpca',
#  'cyberstudies',
#  'palaeoclimate',
#  'condensed_matter',
#  'chronological-storage',
#  '81-02-quantum-theory-research-exposition',
#  'triangles',
#  'role',
#  'ethnographies',
#  'vegetative',
#  'activation_patterns',
#  'ypatch',
#  'preferred_directions',
#  'locality-sensitive',
#  'adaptive_web',
#  'ppi-module',
#  't-imaging',
#  'intent',
#  'hydrogel',
#  'variable',
#  '0_knowledge_representation',
#  'individual-based-modeling',
#  'hawkes',
#  'frances-smith',
#  'electricity_price',
#  'ordination',
#  'wiki_studies',
#  'population_stratification',
#  'decision',
#  'jinhua_zhao_seminar',
#  'cmb_anisotropies',
#  'chain',
#  'digital-collections',
#  'oss',
#  'science_meta_stuff',
#  'problema_cientifico',
#  'osm',
#  'osn',
#  'selectivity',
#  'interaction-design',
#  'salvatore-mele',
#  'thiou',
#  'kenetics',
#  'z-paper-fer1-fer2-species',
#  'amplification',
#  'traffic_dynamics',
#  'cis-reg',
#  'project-cls',
#  'silencers',
#  'free_software',
#  'thiol',
#  'oversight',
#  'polygenic_adaptation',
#  'b03348',
#  'base_calling',
#  'habitat_modelling',
#  'choice',
#  'lambdacdm',
#  'goodref',
#  'comments_analysis',
#  'rationality',
#  'knapsack',
#  'exact',
#  'social_robots',
#  'expr2flux',
#  'qudit',
#  'distributed-database',
#  'defaults',
#  'agentes',
#  'wrmsd',
#  'neuroprosthetics',
#  'two_player_games',
#  'go_nogo',
#  'adorno',
#  'trails',
#  'tip4p-ew',
#  'research_trend',
#  'killback_theory',
#  '3d-feature-extraction',
#  'hypothesis-testing',
#  'phylogenetic_marker_selection',
#  'bagging',
#  'many-core',
#  'david-allison',
#  'evol-game',
#  'pldi00',
#  'distribution_model',
#  'normalmodes',
#  'oer',
#  'ground',
#  'boost',
#  '20101105000006',
#  'encephalization',
#  'oldies',
#  'relational_graph_mining',
#  'geostatistics',
#  'pedagogic',
#  'pedagogia',
#  'ndfrt',
#  'address',
#  'mario-falchi',
#  'neil-swainston',
#  'mscclustering',
#  'level_of_abstraction',
#  'mycobacterium_tuberculosis',
#  'md_simulation',
#  '1000-genomes',
#  'pathway-gwas',
#  'queue',
#  'lifelog',
#  'throughput',
#  'intelligent_transportation_systems',
#  'harpreet-saini',
#  'computational-narratologynarratology',
#  'windowing',
#  'hcls',
#  'fdgh',
#  'ttm-soc',
#  'makeig',
#  'mutation-rate',
#  'sistemas',
#  'hclc',
#  'mut-sel',
#  'forest-pests',
#  'myoglobin',
#  'chromatin_exon_intron',
#  'neurodynamics',
#  'web_viewer',
#  'software_components',
#  'multinaturalism',
#  'google_flu_trends',
#  'perceptual-discrimination',
#  'dataset-interactions',
#  'julie-hoover-fong',
#  'lifshitz-point',
#  'tag_prediction',
#  'socialnet',
#  'semwiki',
#  'varient',
#  'cisreg',
#  'tundra',
#  'gal4_uas_system',
#  'research-paper',
#  'dave-de-roure',
#  'crfs',
#  'seminar-economics-ict',
#  'optmization',
#  'phase-shifting',
#  'gradient-vector-flow',
#  'dna_motor',
#  'movingimagearchives',
#  'opioids',
#  'currency',
#  'oscillator',
#  'molecular-typing',
#  'rangement',
#  'cs8682',
#  'commensals',
#  'zippers',
#  'polarizability',
#  'diffraction_theory',
#  'nanobiology',
#  'gain_modulation',
#  'network-simulator',
#  '1-toposes',
#  'powerspectra',
#  'mirrors',
#  'lodestone',
#  'hypernetworks',
#  'parachute',
#  'locks',
#  'incremental',
#  'mobilenetworks',
#  'dna_microarrays',
#  'crisanna',
#  'probabilistic-model',
#  'usermodelling',
#  'septic',
#  'evolutionary_constraint',
#  'long-read',
#  'delay_tolerant_networking',
#  'aminoacid_substitution_models',
#  'oswaldo',
#  'ot_feature',
#  'touch-technology',
#  'markov_logic_networks',
#  'thetaphysio',
#  'steady_states',
#  'factor_de_impacto',
#  'entanglementtheory',
#  'window_management',
#  'lineage_var',
#  'rating-5',
#  'integrative-distributive',
#  'software_packages',
#  'team-science',
#  'dipole-force',
#  'color-space',
#  'conscious',
#  'network_connectivity',
#  'pac-learning',
#  'itools',
#  'sandbox',
#  'computational-physics',
#  'social-cognition',
#  'philip-lord',
#  'manga',
#  'genome_informatics',
#  'tf_motifs',
#  'shrna',
#  'cheap_talk',
#  'webpage',
#  'exec-control',
#  'structuring',
#  'episodes',
#  'implicit_evidences',
#  'multipath',
#  'mirna_and_cancer',
#  'regulatiory',
#  'zmac',
#  'jif',
#  'jie',
#  'productosnaturales',
#  'jim',
#  'mobile_avatar',
#  'jit',
#  'mid_twentieth_century',
#  'jis',
#  'new-technologies',
#  'method_comparison',
#  'study-bias',
#  'de-novo-design',
#  'ultraconserved_elements',
#  'informationgeometry',
#  'user-attention',
#  'user-identification',
#  'bionlp',
#  'z-dna',
#  'biogps',
#  'mixture-model',
#  'aaarchaeansf',
#  'enzyme_active_sites',
#  'docudigi',
#  'mass_transport',
#  'camon-05',
#  'woese',
#  'thermodynamic_model',
#  'energy-balance',
#  'jmac',
#  'collaborative-intelligence',
#  'transcriptionalnetworks',
#  'visual_world',
#  'instability',
#  'personalizing',
#  'ancestry-information-markers',
#  'prisma',
#  'retrieve',
#  'bursting',
#  'form-extraction',
#  'interactive_spaces',
#  'strand_specific',
#  'disasters',
#  'tc_superconductors',
#  'logic_programs',
#  'e_learning',
#  'crowd_sourcing',
#  'mobilewebusability',
#  '4c',
#  'corpus_muc7',
#  'corpus_muc6',
#  '798',
#  'smith-waterman',
#  'diagnostic_accuracy',
#  'internet',
#  'shared-intention',
#  'specy',
#  'ross_king',
#  'gopubmed',
#  'molecular_methods',
#  'incentives',
#  'diffraction_limit',
#  'stats-meetings',
#  'lit_review',
#  'tissue-evolution',
#  'neutral_evolution',
#  'eliezer',
#  '11sep09',
#  'compton02',
#  'alu_elements',
#  'linear-model',
#  'data_quality_control',
#  'genetics-genomics',
#  'gut-microbiota',
#  'mixed-reality',
#  'geomorphology',
#  'social_psych',
#  'causal_effects',
#  'leopold-parts',
#  'neglect',
#  'emotion',
#  'symmetry',
#  'in_situ_hybridization',
#  'comparative_genomic_hybridization',
#  'parkinson',
#  'duitsland',
#  'defect-cause-analysis',
#  'diversifying_selection',
#  'intrinsic-fitness',
#  'philosophy_science',
#  'tamara',
#  'social-dilemmas',
#  'feature_grouping',
#  'quantum_mechanics',
#  'hanalyzer',
#  'f81',
#  'bdigital',
#  '0_tablet_pc',
#  'cancer-stem-cells',
#  'dev-context',
#  'research-topic',
#  'constants',
#  'is6600',
#  'redundant_systems',
#  'cerebro',
#  'kennismanagement',
#  'augmented-browsing',
#  'mutation-genetics',
#  'ssnmr',
#  'famine',
#  'feature_based',
#  'cscwproject',
#  'diversity_maintainance',
#  'rehab',
#  'aaa_stat_versus_mech_paper',
#  'jkchoi_1st',
#  'wandering',
#  'proactive',
#  'fast-gamma',
#  'concurrency-control',
#  'top_down_systems_biology',
#  'illumina1g',
#  'grns',
lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#find vocabulary_size = 8000
with open(r"data/vocabulary.dat") as vocabulary_file:
    vocabulary_size = len(vocabulary_file.readlines())
    
#find item_size = 16980
with open(r"data/mult.dat") as item_info_file:
    item_size = len(item_info_file.readlines())

#initialize item_infomation_matrix (16980 , 8000)
item_infomation_matrix = np.zeros((item_size , vocabulary_size))

#build item_infomation_matrix
with open(r"data/mult.dat") as item_info_file:
    sentences = item_info_file.readlines()
    
    for index,sentence in enumerate(sentences):
        words = sentence.strip().split(" ")[1:]
        for word in words:
            vocabulary_index , number = word.split(":")
            item_infomation_matrix[index][int(vocabulary_index)] =number

# %%
import numpy as np
rating_matrix = load_user_article_likes('data')
rating_matrix.shape
# Out:
# (5551, 13584)

# %%
class MF():
    def __init__(self , rating_matrix ):
        self.num_u = rating_matrix.shape[0] #5551
        self.num_v = rating_matrix.shape[1] #16980
        self.u_lambda = 100
        self.v_lambda = 0.1
        self.k = 50 
        self.a = 1
        self.b =0.01
        self.R = np.mat(rating_matrix)
        self.C = np.mat(np.ones(self.R.shape)) * self.b
        self.C[np.where(self.R>0)] = self.a
        self.I_U = np.mat(np.eye(self.k) * self.u_lambda)
        self.I_V = np.mat(np.eye(self.k) * self.v_lambda)
        self.U = np.mat(np.random.normal(0 , 1/self.u_lambda , size=(self.k,self.num_u)))
        self.V = np.mat(np.random.normal(0 , 1/self.v_lambda , size=(self.k,self.num_v)))
                        

    def test(self):
        print( ((U_cut*self.R[np.ravel(np.where(self.R[:,j]>0)[1]),j] + self.v_lambda * self.V_sdae[j])).shape)
    def ALS(self , V_sdae):
        self.V_sdae = np.mat(V_sdae)
        
        V_sq = self.V * self.V.T * self.b
        for i in range(self.num_u):
            idx_a = np.ravel(np.where(self.R[i,:]>0)[1])
            V_cut = self.V[:,idx_a]
            self.U[:,i] = np.linalg.pinv( V_sq+ V_cut * V_cut.T * (self.a-self.b) + self.I_U )*(V_cut*self.R[i,idx_a].T) #V_sq+V_cut*V_cut.T*a_m_b = VCV^T
        
        U_sq = self.U * self.U.T * self.b
        for j in range(self.num_v):
            idx_a = np.ravel(np.where(self.R[:,j]>0)[1])
            U_cut = self.U[:,idx_a]
            self.V[:,j] = np.linalg.pinv(U_sq+U_cut*U_cut.T*(self.a-self.b)+self.I_V)* (U_cut*self.R[idx_a,j] + self.v_lambda * np.resize(self.V_sdae[j],(self.k,1)))
        
        return self.U ,self.V

# %%
def mask(corruption_level ,size):
    mask = np.random.binomial(1, 1 - corruption_level, [size[0],size[1]])
    return mask

def add_noise(x , corruption_level ):
    x = x * mask(corruption_level , x.shape)
    return x

# %%
class CDL():
    def __init__(self , rating_matrix , item_infomation_matrix):
        
        self.n_input = item_infomation_matrix.shape[1]
        self.n_hidden1 = 200
        self.n_hidden2 = 50
        self.k = 50
        
        self.lambda_w = 0.1
        self.lambda_n = 10
        self.lambda_u = 1
        self.lambda_v = 10
        
        self.drop_ratio = 0.1
        self.learning_rate = 0.01
        self.epochs = 2
        self.batch_size = 256
        
        self.a = 1
        self.b =0.01
        self.P = 1
        
        self.num_u = rating_matrix.shape[0]
        self.num_v = rating_matrix.shape[1]
        
        self.Weights = {
            'w1' : tf.Variable(tf.truncated_normal( [self.n_input , self.n_hidden1] , mean=0.0, stddev= tf.truediv(1.0,self.lambda_w))),
            'w2' : tf.Variable(tf.truncated_normal( [self.n_hidden1 , self.n_hidden2] , mean=0.0, stddev= tf.truediv(1.0,self.lambda_w))),
            'w3' : tf.Variable(tf.truncated_normal( [self.n_hidden2 , self.n_hidden1] , mean=0.0, stddev= tf.truediv(1.0,self.lambda_w))),
            'w4' : tf.Variable(tf.truncated_normal( [self.n_hidden1 , self.n_input] , mean=0.0,  stddev= tf.truediv(1.0,self.lambda_w)))   
        }
        self.Biases = {
            'b1' : tf.Variable( tf.zeros(shape=self.n_hidden1) ),
            'b2' : tf.Variable( tf.zeros(shape=self.n_hidden2) ),
            'b3' : tf.Variable( tf.zeros(shape=self.n_hidden1) ),
            'b4' : tf.Variable( tf.zeros(shape=self.n_input) ),
        }
        
        self.item_infomation_matrix = item_infomation_matrix
        
        self.rating_matrix = rating_matrix
        
        for i in range(self.num_u):
            try:
                x = np.random.choice(np.where(self.rating_matrix[i,:]>0)[0] , self.P)
            except:
                x=1
            self.rating_matrix[i,:].fill(0)
            self.rating_matrix[i,x] = 1
        
        self.confidence = np.mat(np.ones(self.rating_matrix.shape)) * self.b
        self.confidence[np.where(self.rating_matrix>0)] = self.a
        
    def encoder(self , x , drop_ratio):
        w1, b1 = self.Weights['w1'], self.Biases['b1']
        L1 = tf.nn.sigmoid( tf.matmul(x,w1) + b1 )
        L1 = tf.nn.dropout( L1 , keep_prob= 1 - drop_ratio )
        
        w2, b2 = self.Weights['w2'],self.Biases['b2']
        
        L2 = tf.nn.sigmoid( tf.matmul(L1,w2) + b2 )
        L2 = tf.nn.dropout(L2 , keep_prob= 1 - drop_ratio)
        
        return L2
    
    def decoder(self , x , drop_ratio):
        w3, b3 = self.Weights['w3'], b2 = self.Biases['b3']
        L3 = tf.nn.sigmoid(tf.matmul(x,w3) + b3)
        L3 = tf.nn.dropout(L3 , keep_prob= 1 - drop_ratio)

        w4, b4 = self.Weights['w4'], self.Biases['b4']
        L4 = tf.nn.sigmoid(tf.matmul(L3,w4) + b4)
        L4 = tf.nn.dropout(L4 , keep_prob= 1 - drop_ratio)

        return L4
    

    def build_model(self):
        
        self.X_0 = tf.placeholder(tf.float32 , shape=(None , self.n_input))
        self.X_c = tf.placeholder(tf.float32 , shape=(None , self.n_input))
        self.C = tf.placeholder(tf.float32 , shape=(self.num_u,None) )
        self.R = tf.placeholder(tf.float32 , shape=(self.num_u,None) )
        self.drop_ratio = tf.placeholder(tf.float32)
        self.model_batch_data_idx = tf.placeholder( tf.int32 , shape=None )
        
        #SDAE item factor
        V_sdae = self.encoder(self.X_0, self.drop_ratio )
        
        #SDAE output 
        sdae_output = self.decoder( V_sdae, self.drop_ratio )
        
        
        
        
        batch_size = tf.cast(tf.shape(self.X_0)[0], tf.int32)
        
        
        self.V = tf.Variable( tf.zeros(shape=[self.num_v, self.k], dtype=tf.float32 ) ) 
        self.U = tf.Variable( tf.zeros(shape=[self.num_u, self.k], dtype=tf.float32 ) )
        
        batch_V = tf.reshape(tf.gather(self.V, self.model_batch_data_idx), shape=[batch_size, self.k])
        
        loss_1 = self.lambda_u * tf.nn.l2_loss( self.U ) 
        loss_2 = self.lambda_w * 1/2 * tf.reduce_sum([tf.nn.l2_loss(w)+tf.nn.l2_loss(b) for w,b in zip(self.Weights.values() , self.Biases.values())])
        loss_3 = self.lambda_v * tf.nn.l2_loss(batch_V - V_sdae)
        loss_4 = self.lambda_n * tf.nn.l2_loss(sdae_output - self.X_c)
        
        loss_5 = tf.reduce_sum(tf.multiply(self.C ,
                                    tf.square(self.R - tf.matmul(self.U , batch_V , transpose_b=True))) 
                                )
        
        self.loss = loss_1 + loss_2 + loss_3 + loss_4 + loss_5
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss)
        
    def train_model(self):
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        
        start_time = time.time()
        
        random_idx = np.random.permutation(self.num_v)
        
        self.item_infomation_matrix_noise = add_noise(self.item_infomation_matrix , 0.3)
        
        for epoch in range(self.epochs):
            batch_cost = 0
            for i in range(0 , self.item_infomation_matrix.shape[0] , self.batch_size):
                
                batch_idx = random_idx[i:i+self.batch_size]
                _ , loss = self.sess.run([self.optimizer, self.loss] , 
                                            feed_dict={self.X_0 : self.item_infomation_matrix_noise[batch_idx,:] , 
                                                       self.X_c : self.item_infomation_matrix[batch_idx,:] , 
                                                       self.R : self.rating_matrix[: , batch_idx], 
                                                       self.C : self.confidence[: , batch_idx], 
                                                       self.drop_ratio : 0.1 ,
                                                       self.model_batch_data_idx  : batch_idx })
                batch_cost = batch_cost + loss

            print ("Training //", "Epoch %d //" % (epoch+1), " Total cost = {:.2f}".format(batch_cost), "Elapsed time : %d sec" % (time.time() - start_time))
            
        return self.sess.run((tf.matmul(self.U, self.V, transpose_b=True)))

# %%
R_train = rating_matrix.copy()
cdl = CDL(R_train , item_infomation_matrix)
cdl.build_model()
R = cdl.train_model()
# Out:
# Training // Epoch 1 //  Total cost = 657817522.00 Elapsed time : 22 sec
# Training // Epoch 2 //  Total cost = 517610760.50 Elapsed time : 41 sec

# %%
all_cnt = 0
for i in range(rating_matrix.shape[0]):
    l_score = np.ravel(R[i,:]).tolist()
    pl = sorted(enumerate(l_score),key=lambda d:d[1],reverse=True)
    l_rec = [i[0] for i in pl][:300]
    s_rec = set(l_rec)
    s_true = set(np.ravel(np.where(rating_matrix[i,:]>0)))
    cnt_hit = len(s_rec.intersection(s_true))
    all_cnt = all_cnt + cnt_hit/len(s_true)
all_cnt
# Out:
# 1577.0

# %%
np.where(rating_matrix[i,:]>0), sum(rating_matrix), set(np.ravel(np.where(rating_matrix[0,:]>0)))
# Out:
# ((array([], dtype=int64),),
#  array([18., 23., 80., ...,  4., 10.,  7.]),
#  {11650})

# %%
R.shape
# Out:
# (5551, 13584)
